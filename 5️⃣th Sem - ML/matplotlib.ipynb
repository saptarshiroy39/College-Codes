# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([100, 230])
ypoints = np.array([300, 270])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = np.array([1, 5, 9, 10, 5])
ypoints = np.array([2, 7, 2, 8, 9])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

ypoints = np.array([2, 7, 2, 8, 9])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = np.array([100, 200, 300, 400])
ypoints = np.array([300, 200, 400, 100])

plt.plot(xpoints, ypoints, marker="o", linestyle="dashed", color="r")
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = np.array([100, 200, 300, 400])
ypoints = np.array([300, 200, 400, 100])

plt.plot(xpoints, ypoints, marker="s", linestyle="dotted", color="g")

# %%
import numpy as np
import matplotlib.pyplot as plt

study_hours = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10])
exam_scores = np.array([50, 55, 60, 62, 65, 70, 75, 80, 87])

plt.plot(study_hours, exam_scores, marker="o", linestyle="dashed", color="b")
plt.xlabel("Study Hours per Week")
plt.ylabel("Exam Score (%)")
plt.title("Relationship between Study Hours and Performance")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xpoints = np.array([20.0, 21.3, 25.5, 26.6, 30, 31.8, 35.0, 37, 40])
ypoints = np.array([100, 160, 200, 280, 320, 400, 500, 550, 600])

plt.plot(xpoints, ypoints, marker="o", linestyle="dashed", color="r")
plt.xlabel("Temperature (ºC")
plt.ylabel("IceCream Sales ($)")
plt.title("Effect of Temperatue on IceCreams Sales")
plt.grid(True, color="grey", linestyle=":")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

student = np.array(["A", "B", "C", "D", "E"])
math = np.array([82, 85, 78, 86, 85])
science = np.array([80, 85, 83, 86, 87])
english = np.array([75, 80, 68, 85, 84])

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.bar(student, math, color="blue")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Math Scores")
# plt.show()

plt.subplot(1, 3, 2)
plt.bar(student, science, color="green")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Science Scores")
# plt.show()

plt.subplot(1, 3, 3)
plt.bar(student, english, color="red")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("English Scores")
# plt.show()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

week = np.array(["MON", "TUE", "WED", "THU", "FRI", "SAT", "SUN"])
temp = np.array([30, 32, 31, 29, 28, 27, 26])
humid = np.array([40, 45, 38, 37, 35, 33, 30])
rain = np.array([5, 0, 3, 0, 1, 7, 10])

plt.figure(figsize=(10, 5))

plt.subplot(3, 1, 1)
plt.plot(week, temp, color="red", marker="o")
plt.xlabel("Days")
plt.ylabel("ºC")
plt.title("Daily Tempearature")
# plt.show()

plt.subplot(3, 1, 2)
plt.plot(week, humid, color="blue", marker="s")
plt.xlabel("Days")
plt.ylabel("%")
plt.title("Daily Humidity")
# plt.show()

plt.subplot(3, 1, 3)
plt.bar(week, rain, color="purple")
plt.xlabel("Days")
plt.ylabel("mm")
plt.title("Daily Rainfall")
# plt.show()

plt.tight_layout()
plt.show()
